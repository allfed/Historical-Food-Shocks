# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
os.chdir('../')
print(os.getcwd())
# Out:
# /home/florian/Documents/GitHub/Historical-Food-Shocks

# %%
# Read the data from results folder
df = pd.read_csv('results/calories_by_countries.csv', index_col=0)
df.describe()
# Out:
#                1961          1962          1963          1964          1965  \
# count  1.760000e+02  1.760000e+02  1.760000e+02  1.760000e+02  1.760000e+02
# mean   2.016722e+13  2.130856e+13  2.196724e+13  2.335028e+13  2.347409e+13
# std    7.166096e+13  7.393333e+13  7.687860e+13  8.206520e+13  8.457312e+13
# min    8.970000e+06  8.970000e+06  8.970000e+06  1.084000e+07  1.084000e+07
# 25%    3.416775e+11  3.621368e+11  3.625637e+11  3.711100e+11  3.875472e+11
# 50%    2.178340e+12  2.343586e+12  2.361290e+12  2.421063e+12  2.563142e+12
# 75%    9.205381e+12  1.010192e+13  1.053763e+13  1.137640e+13  1.166939e+13
# max    6.318431e+14  6.267893e+14  6.810247e+14  6.361663e+14  7.247438e+14
#
#                1966          1967          1968          1969          1970  \
# count  1.760000e+02  1.760000e+02  1.760000e+02  1.760000e+02  1.760000e+02
# mean   2.523500e+13  2.625019e+13  2.712282e+13  2.721821e+13  2.807170e+13
# std    9.272275e+13  9.611876e+13  9.824401e+13  9.789109e+13  1.023498e+14
# min    1.033000e+07  1.033000e+07  1.050000e+07  1.081000e+07  1.272000e+07
# 25%    4.047658e+11  3.988448e+11  3.692912e+11  3.700508e+11  3.146515e+11
# 50%    2.515376e+12  2.529603e+12  2.747091e+12  2.733144e+12  2.698230e+12
# 75%    1.049960e+13  1.228818e+13  1.211764e+13  1.254393e+13  1.283369e+13
# max    7.349166e+14  8.206481e+14  8.119176e+14  8.236141e+14  8.307797e+14
#
#        ...          2014          2015          2016          2017  \
# count  ...  1.990000e+02  1.990000e+02  1.990000e+02  1.990000e+02
# mean   ...  6.745653e+13  6.790558e+13  6.951921e+13  7.153566e+13
# std    ...  2.522894e+14  2.595269e+14  2.705115e+14  2.688950e+14
# min    ...  4.367540e+08  4.489418e+08  4.541035e+08  4.633333e+08
# 25%    ...  7.200836e+11  7.269300e+11  6.626232e+11  6.876781e+11
# 50%    ...  6.917073e+12  6.720487e+12  7.212906e+12  7.556738e+12
# 75%    ...  2.705339e+13  2.582320e+13  2.747140e+13  2.737607e+13
# max    ...  2.354749e+15  2.541755e+15  2.530098e+15  2.541020e+15
#
#                2018          2019          2020          2021          2022  \
# count  1.990000e+02  1.990000e+02  1.990000e+02  1.990000e+02  1.990000e+02
# mean   7.063134e+13  7.169382e+13  7.246031e+13  7.441258e+13  7.438513e+13
# std    2.683481e+14  2.677639e+14  2.733634e+14  2.808893e+14  2.789592e+14
# min    4.402815e+08  4.194774e+08  4.143693e+08  4.091074e+08  4.139119e+08
# 25%    6.451622e+11  6.223604e+11  6.762649e+11  6.158941e+11  7.065914e+11
# 50%    7.190922e+12  7.801481e+12  7.617692e+12  7.638406e+12  8.130588e+12
# 75%    2.743458e+13  2.832039e+13  3.032244e+13  3.077111e+13  3.041752e+13
# max    2.538531e+15  2.571954e+15  2.583766e+15  2.631382e+15  2.652255e+15
#
#                2023
# count  1.990000e+02
# mean   7.643963e+13
# std    2.915509e+14
# min    4.330790e+08
# 25%    6.620913e+11
# 50%    7.540119e+12
# 75%    3.042252e+13
# max    2.683439e+15
#
# [8 rows x 63 columns]

# %%
df.head()
# Out:
#                              1961          1962          1963          1964  \
# Area
# Afghanistan          1.291046e+13  1.298313e+13  1.200640e+13  1.313053e+13
# Albania              1.113125e+12  1.149222e+12  1.130428e+12  1.342657e+12
# Algeria              4.342251e+12  9.000276e+12  8.845490e+12  5.892183e+12
# Angola               3.820581e+12  3.876027e+12  3.795464e+12  4.010846e+12
# Antigua and Barbuda  5.629072e+10  6.011223e+10  7.853213e+10  7.831581e+10
#
#                              1965          1966          1967          1968  \
# Area
# Afghanistan          1.333132e+13  1.231236e+13  1.353254e+13  1.383816e+13
# Albania              1.260557e+12  1.684231e+12  1.872115e+12  1.916072e+12
# Algeria              7.048542e+12  3.339824e+12  6.183885e+12  8.096068e+12
# Angola               4.116635e+12  3.984338e+12  4.098779e+12  4.184387e+12
# Antigua and Barbuda  4.105642e+10  2.501420e+10  1.593064e+10  4.392130e+09
#
#                              1969          1970  ...          2014  \
# Area                                             ...
# Afghanistan          1.429459e+13  1.245042e+13  ...  2.453481e+13
# Albania              1.962353e+12  2.000780e+12  ...  2.759073e+12
# Algeria              7.098880e+12  7.804783e+12  ...  1.586128e+13
# Angola               4.798342e+12  4.631016e+12  ...  1.990432e+13
# Antigua and Barbuda  1.295601e+10  1.350662e+10  ...  1.434569e+09
#
#                              2015          2016          2017          2018  \
# Area
# Afghanistan          2.116553e+13  2.036342e+13  1.820644e+13  1.578375e+13
# Albania              2.761367e+12  2.779236e+12  2.789536e+12  2.709067e+12
# Algeria              1.690394e+13  1.600401e+13  1.608219e+13  2.460810e+13
# Angola               2.076545e+13  2.231604e+13  2.300998e+13  2.486776e+13
# Antigua and Barbuda  1.473008e+09  1.342122e+09  1.137307e+09  9.134530e+08
#
#                              2019          2020          2021          2022  \
# Area
# Afghanistan          2.113118e+13  2.267100e+13  1.846245e+13  1.785487e+13
# Albania              2.690355e+12  2.739703e+12  2.792539e+12  2.786026e+12
# Algeria              2.360159e+13  1.937130e+13  1.388811e+13  1.816350e+13
# Angola               2.542081e+13  2.685034e+13  2.728337e+13  2.870379e+13
# Antigua and Barbuda  9.041071e+08  7.723350e+08  8.212530e+08  9.607221e+08
#
#                              2023
# Area
# Afghanistan          1.987262e+13
# Albania              2.807770e+12
# Algeria              1.681487e+13
# Angola               3.039223e+13
# Antigua and Barbuda  1.031752e+09
#
# [5 rows x 63 columns]

# %%
plt.figure(figsize=(10, 60))
sns.heatmap(df)
# Out:
# <Axes: ylabel='Area'>

# %%
# Sort by the values in 2023 and plot the heatmap again, but only for the top 10
df_sorted = df.sort_values(by='2023', ascending=False)
df_sorted.head(10)
plt.figure(figsize=(10, 8))
sns.heatmap(df_sorted.head(10))
# Out:
# <Axes: ylabel='Area'>

# %%
# Do the same for the yield_changes.csv
df_yield = pd.read_csv('results/yield_changes_by_countries.csv', index_col=0)
df_yield.describe()
# Out:
#              1961        1962        1963        1964        1965        1966  \
# count  176.000000  176.000000  176.000000  176.000000  176.000000  176.000000
# mean     0.708393    0.496711   -0.844790    0.499639   -0.267077   -2.158190
# std      8.915741    9.204072   14.389036   12.239535   10.933251   12.075345
# min    -38.499389  -46.436136  -55.355255  -25.739867  -25.601911  -50.924247
# 25%     -2.094869   -3.406989   -6.698912   -4.478463   -4.993021   -5.478394
# 50%      0.608633    0.043786   -1.586412   -0.568442   -0.619510   -0.931888
# 75%      3.912949    2.915002    4.473714    3.678845    2.860394    3.581754
# max     28.415644   38.650770  131.920799   74.433915   72.660191   64.488327
#
#              1967        1968        1969        1970  ...        2014  \
# count  176.000000  176.000000  176.000000  176.000000  ...  199.000000
# mean     2.653587   -0.447928    1.135249   -0.756686  ...    2.195999
# std     14.367247   12.224989   10.856696   14.996404  ...   13.404910
# min    -47.828880  -81.488297  -50.369777  -78.606680  ...  -57.559301
# 25%     -2.409370   -5.285465   -4.003564   -6.051458  ...   -2.469865
# 50%      1.362882    0.887382    1.060409   -0.112126  ...    2.001975
# 75%      6.428816    5.382265    6.215003    4.260792  ...    7.364257
# max    107.968548   41.561039   41.799762   62.602200  ...   68.842317
#
#              2015        2016        2017        2018        2019        2020  \
# count  199.000000  199.000000  199.000000  199.000000  199.000000  199.000000
# mean     0.157278   -1.365606   -0.019906   -2.126499   -0.221831    0.974574
# std     12.699723   13.906894   15.225442   13.271407   11.919616   12.705961
# min    -45.680069  -60.149948  -63.633814  -56.105956  -45.116171  -51.564241
# 25%     -5.398500   -5.415606   -5.042570   -6.223288   -3.043368   -2.916542
# 50%     -0.052615   -0.301780   -0.050745   -0.000619    0.376652    0.514685
# 75%      4.331640    4.384601    3.622714    3.047087    3.721598    4.759205
# max     46.271945   73.030883  105.351144   62.770213   64.400833   73.385996
#
#              2021        2022        2023
# count  199.000000  199.000000  199.000000
# mean     0.713130   -0.001471    0.466807
# std     10.750462   10.224266   10.338224
# min    -33.742938  -38.630241  -26.837476
# 25%     -2.609391   -3.040550   -3.442475
# 50%      0.527916    0.178416   -0.216554
# 75%      3.687577    3.509998    2.872932
# max     48.909067   43.721027  104.106338
#
# [8 rows x 63 columns]

# %%
df_yield.head()
# Out:
#                           1961       1962       1963       1964       1965  \
# Area
# Afghanistan           2.789743   1.126284  -7.619428   0.509945   2.001643
# Albania               7.033204   1.069639  -8.985885  -0.763212 -14.129439
# Algeria             -32.140889  35.676665  30.632155 -13.759558   3.095878
# Angola               -0.785568   1.276476  -1.512723   2.331744   2.579534
# Antigua and Barbuda -18.614776  -6.404411  34.571725  51.167820  -8.402222
#
#                           1966       1967       1968       1969       1970  \
# Area
# Afghanistan          -5.605367   3.978776   6.342625   8.473635  -8.534718
# Albania               6.255163   9.970496   5.397938   3.572463   0.550958
# Algeria             -50.924247  -8.499394  20.553123   9.795793  11.364315
# Angola               -3.377316  -3.325772  -3.818622   8.650352   3.327512
# Antigua and Barbuda -33.560645 -47.828880 -81.488297 -20.504164  36.451905
#
#                      ...       2014       2015       2016       2017  \
# Area                 ...
# Afghanistan          ...  15.649312  -1.463451  -1.192670  -9.837348
# Albania              ...  -1.502328  -0.738654   0.259880   1.305984
# Algeria              ... -17.557027 -13.653004 -15.264238 -16.429606
# Angola               ... -11.885562  -8.919254  -2.243607  -1.644413
# Antigua and Barbuda  ...   5.359208  13.973621  10.574482   2.649325
#
#                           2018       2019       2020       2021      2022  \
# Area
# Afghanistan         -20.260506   8.629519  18.031399  -3.332398 -6.840914
# Albania              -0.986342  -1.254918   0.571749   1.922047  0.329717
# Algeria              26.321926  20.930902   0.514685 -25.600423  3.079432
# Angola                3.098110   1.604971   2.856347  -0.391069 -0.645546
# Antigua and Barbuda  -9.428035  -2.453948 -11.654185  -4.722890  6.579901
#
#                          2023
# Area
# Afghanistan          2.181056
# Albania             -1.141244
# Algeria              4.740351
# Angola              -0.736666
# Antigua and Barbuda  2.775835
#
# [5 rows x 63 columns]

# %%
df_yield.max().max()
# Out:
# np.float64(794.8255165952863)

# %%
df_yield.min().min()
# Out:
# np.float64(-1289.958229521255)

# %%
plt.figure(figsize=(10, 60))
sns.heatmap(df_yield, vmax=100, vmin=-100, cmap="RdYlBu")
# Out:
# <Axes: ylabel='Area'>

# %%
# print largest shock in China
df_yield.loc['China'].min()
# Out:
# np.float64(-7.145162835733522)

# %%
# Now only plot values below - 5 
df_yield_below_5 = df_yield[df_yield < -5]
plt.figure(figsize=(10, 60))
sns.heatmap(df_yield_below_5, vmax=0, vmin=-100, cmap="Oranges_r")
# Out:
# <Axes: ylabel='Area'>

# %%
# Count the yield shocks above 5 for each year and plot as a bar plot
df_yield_below_5_count = df_yield_below_5.count()
plt.figure(figsize=(10, 5))
sns.barplot(x=df_yield_below_5_count.index, y=df_yield_below_5_count.values)
plt.xticks(rotation=90)
plt.xlabel('Year')
plt.ylabel('Count')
plt.title('Count of yield shocks below -5%')
# Out:
# Text(0.5, 1.0, 'Count of yield shocks below -5%')
