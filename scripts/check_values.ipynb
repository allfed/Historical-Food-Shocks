# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
os.chdir('../')
print(os.getcwd())
# Out:
# /home/florian/Documents/GitHub/Historical-Food-Shocks

# %%
# Read the data from results folder
df = pd.read_csv('results/calories.csv', index_col=0)
df.describe()
# Out:
#                1961          1962          1963          1964          1965  \
# count  2.080000e+02  2.080000e+02  2.080000e+02  2.080000e+02  2.080000e+02
# mean   7.132905e+13  7.547532e+13  7.791561e+13  8.288802e+13  8.327211e+13
# std    2.764818e+14  2.918401e+14  3.012435e+14  3.214003e+14  3.226428e+14
# min    6.000000e+06  6.000000e+06  6.000000e+06  6.600000e+06  6.600000e+06
# 25%    4.547642e+11  5.510011e+11  5.137000e+11  5.282061e+11  5.475149e+11
# 50%    3.358357e+12  3.439218e+12  3.351987e+12  3.536099e+12  3.555684e+12
# 75%    3.089607e+13  3.028050e+13  3.107765e+13  3.167117e+13  3.223182e+13
# max    3.302958e+15  3.494551e+15  3.598946e+15  3.833854e+15  3.835917e+15
#
#                1966          1967          1968          1969          1970  \
# count  2.080000e+02  2.080000e+02  2.080000e+02  2.080000e+02  2.080000e+02
# mean   8.923542e+13  9.334074e+13  9.590142e+13  9.648038e+13  9.951847e+13
# ...

# %%
df.head()
# Out:
#                      1961          1962          1963          1964  \
# Area
# Afghanistan  1.277814e+13  1.278073e+13  1.172051e+13  1.292813e+13
# Africa       1.957568e+14  2.203530e+14  2.261188e+14  2.171863e+14
# Albania      1.068850e+12  1.104441e+12  1.074768e+12  1.286997e+12
# Algeria      4.335647e+12  8.993825e+12  8.839039e+12  5.885542e+12
# Americas     8.549179e+14  8.839479e+14  9.711545e+14  9.440220e+14
#
#                      1965          1966          1967          1968  \
# Area
# Afghanistan  1.313650e+13  1.215297e+13  1.335291e+13  1.365347e+13
# Africa       2.228377e+14  2.176464e+14  2.621255e+14  2.521172e+14
# Albania      1.198400e+12  1.621879e+12  1.816721e+12  1.884168e+12
# Algeria      7.041117e+12  3.334653e+12  6.178282e+12  8.089862e+12
# Americas     1.035403e+15  1.071476e+15  1.155371e+15  1.134298e+15
#
#                      1969          1970  ...          2014          2015  \
# Area                                     ...
# ...

# %%
# Remove the rows with index World, Asia, Americas, Eastern Asia, Southern Asia, Northern America, Europe
df = df.drop(['World', 'Asia', 'Americas', 'Eastern Asia', 'Southern Asia', 'Northern America', 'Europe'])

# %%
plt.figure(figsize=(10, 60))
sns.heatmap(df)
# Out:
# <Axes: ylabel='Area'>

# %%
# Sort by the values in 2023 and plot the heatmap again, but only for the top 10
df_sorted = df.sort_values(by='2023', ascending=False)
df_sorted.head(10)
plt.figure(figsize=(10, 8))
sns.heatmap(df_sorted.head(10))
# Out:
# <Axes: ylabel='Area'>

# %%
# Plot only Singapore
df_singapore = df.loc[['Singapore']]
plt.figure(figsize=(20, 1))
sns.heatmap(df_singapore)
# Out:
# <Axes: ylabel='Area'>

# %%
# Print all years for Singapore
# Don't let them cut off
print(df_singapore.to_string(index=True))
# Out:
#                    1961          1962          1963          1964          1965          1966          1967          1968          1969          1970          1971          1972          1973          1974          1975          1976          1977          1978          1979          1980          1981          1982          1983          1984          1985         1986         1987         1988         1989         1990         1991         1992        1993        1994        1995        1996       1997      1998       1999       2000      2001      2002        2003        2004        2005         2006         2007        2008         2009         2010         2011         2012         2013         2014         2015         2016         2017         2018         2019         2020         2021         2022         2023
# Area
# ...

# %%
# Do the same for the yield_changes.csv
df_yield = pd.read_csv('results/yield_changes.csv', index_col=0)
df_yield.describe()
# Out:
#              1961        1962        1963        1964        1965        1966  \
# count  170.000000  170.000000  170.000000  170.000000  170.000000  170.000000
# mean    -0.207792    0.891682    0.032337    0.587636   -0.256472   -2.160771
# std      7.632673    9.313201   13.292958    9.843036    9.752765   12.518953
# min    -32.637560  -48.426847  -53.699184  -39.158724  -37.352495  -49.336137
# 25%     -1.811766   -2.532341   -4.791341   -2.470067   -4.341039   -5.441509
# 50%     -0.138948    0.331450   -0.781566    0.062861   -0.111006   -0.995979
# 75%      2.364939    3.643701    3.833805    3.631560    3.194414    2.592220
# max     40.120746   38.650770  131.920799   74.433915   59.664379   77.195229
#
#              1967        1968        1969        1970  ...        2014  \
# count  170.000000  170.000000  170.000000  170.000000  ...  189.000000
# mean     2.493787   -0.502785    1.105487   -1.020278  ...    1.836763
# ...

# %%
df_yield.head()
# Out:
#                   1961       1962       1963       1964       1965       1966  \
# Area
# Afghanistan  -1.306273   3.165992  -4.299666   4.247774   3.196221  -7.302172
# Albania      -1.680456   4.738211  -2.875830   5.355206 -13.005398   4.459124
# Algeria     -30.154904  32.819839  26.318803 -15.665901   3.406013 -49.336137
# Angola       -0.629222   0.676858  -1.639558   2.162596   3.960141  -2.816819
# Argentina     4.101551  -9.053424   0.484632  15.917823 -16.191673   0.536882
#
#                  1967       1968      1969       1970  ...       2014  \
# Area                                                   ...
# Afghanistan  2.353412   5.082324  9.184597  -5.884519  ...  14.459507
# Albania      7.386046   3.628648  0.314152  -2.665854  ...  -1.274790
# Algeria      1.991015  23.627974 -1.196829  10.905540  ...  -8.196933
# Angola      -3.311863  -3.823823  7.447850   1.981808  ...  -9.624381
# Argentina    6.463565  -9.725293  0.607576   2.094624  ...  -6.676361
#
# ...

# %%
df_yield.max().max()
# Out:
# np.float64(160.818079622145)

# %%
df_yield.min().min()
# Out:
# np.float64(-82.50875070684594)

# %%
plt.figure(figsize=(10, 60))
sns.heatmap(df_yield, vmax=100, vmin=-100, cmap="RdYlBu")
# Out:
# <Axes: ylabel='Area'>

# %%
# Now only plot values below - 5 
df_yield_below_5 = df_yield[df_yield < -5]
plt.figure(figsize=(10, 60))
sns.heatmap(df_yield_below_5, vmax=0, vmin=-100, cmap="Oranges_r")
# Out:
# <Axes: ylabel='Area'>

# %%
# Count the yield shocks above 5 for each year and plot as a bar plot
df_yield_below_5_count = df_yield_below_5.count()
plt.figure(figsize=(10, 5))
sns.barplot(x=df_yield_below_5_count.index, y=df_yield_below_5_count.values)
plt.xticks(rotation=90)
plt.xlabel('Year')
plt.ylabel('Count')
plt.title('Count of yield shocks below -5%')
# Out:
# Text(0.5, 1.0, 'Count of yield shocks below -5%')
